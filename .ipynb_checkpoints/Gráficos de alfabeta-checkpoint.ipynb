# %% [markdown]
# # Función Alfa-Beta

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.cm import get_cmap
import sympy as sp

# Símbolos
r, b, alpha, mu = sp.symbols('r b alpha mu', real=True)

# %%
def f3rees1(r2, b, mu2):
    sqrt21 = np.sqrt(21)
    sqrt_term = np.sqrt(-7 + 144*b)

    A = 49 + 54*b*(-21 + sqrt21*sqrt_term)

    denom_common = (-23328*b**2 
                    - 7*sqrt21*sqrt_term 
                    + 162*b*(7 + sqrt21*sqrt_term))

    denom2 = (-7*7**(1/3) 
              + 108*7**(1/3)*b 
              + A**(2/3))

    # Parte interna de la raíz grande
    inner_sqrt = (
        b * (
            9*b*(-7 + 144*b)*r2**8
            - (7**(2/3)*(-7 + 144*b)*(-7 + 162*b)*A**(4/3)*r2**4*mu2)
              / (denom_common * denom2)
            + (243*7**(1/3)*(7 - 144*b)**2 * b * A**(8/3) * mu2**2)
              / ((-denom_common)**2 * denom2**2)
        )
    )

    big_term = (
        -7*(-7 + 162*b)*r2**4
        + (486*7**(2/3)*b*(-7 + 144*b)*A**(4/3)*mu2)
          / (denom_common * denom2)
        + 18*sqrt21*np.sqrt(inner_sqrt)
    )

    term1 = (1 / 7**(2/3)) * r2**(2/3) * big_term**(1/3)

    # Segunda parte
    big_term2 = (
        -49*(-7 + 162*b)*r2**4
        + (3402*7**(2/3)*b*(-7 + 144*b)*A**(4/3)*mu2)
          / (denom_common * denom2)
        + 126*sqrt21*np.sqrt(inner_sqrt)
    )

    term2 = ((7 - 108*b) * r2**(10/3)) / (big_term2**(1/3))

    return 1 + r2**2 + term1 + term2

# %%
r_vals = np.linspace(0, 10, 10000)
mu_list = [0.05, 0.1, 0.2, 0.5, 1, 2, 4, 8]
b_list = [round(8/108,4), 1/8, 1/4,1/2,1,2,4]
alpha_list = [0.03,0.1, 0.5, 1.0]

plt.rcParams.update({
    "font.family": "serif",
    "font.size": 12,
    "figure.dpi": 300,
    "axes.labelsize": 14,
    "axes.titlesize": 16,
    "legend.fontsize": 10,
    "lines.linewidth": 2
})

# Colormap profesional tipo arcoiris
cmap = get_cmap("turbo")   # O "viridis", "plasma", "rainbow"

# Crear grilla de subplots
fig, axes = plt.subplots(
    nrows=len(b_list),
    ncols=len(alpha_list),
    figsize=(4 * len(alpha_list), 3.5 * len(b_list)),
    sharex=True,
    sharey=True
)

# Asegurar que axes siempre sea 2D
axes = np.atleast_2d(axes)

for i, b in enumerate(b_list):
    for j, alpha in enumerate(alpha_list):
        ax = axes[i, j]

        for k, mu in enumerate(mu_list):
            color = cmap(k / (len(mu_list) - 1))
            ax.plot(
                r_vals,
                f(r_vals, b, alpha, mu),
                color=color
            )

        ax.set_title(fr"$b={b},\ \alpha={alpha}$")
        ax.grid(True, alpha=0.3)

        if i == len(b_list) - 1:
            ax.set_xlabel("$r$")
        if j == 0:
            ax.set_ylabel("$f(r)$")

# Leyenda común
handles = [
    plt.Line2D([0], [0], color=cmap(k/(len(mu_list)-1)), lw=2)
    for k in range(len(mu_list))
]
labels = [fr"$\mu={mu}$" for mu in mu_list]

fig.legend(
    handles, labels,
    title="Valores de $\mu$",
    loc="lower center",
    ncol=len(mu_list),
    frameon=True,
    fontsize=18,        # ← tamaño de la leyenda
    title_fontsize=16   # ← tamaño del título
)
plt.savefig("alfa-beta.png", dpi=300, bbox_inches="tight")
plt.tight_layout(rect=[0, 0, 1, 0.92])
plt.show()
# Out:
# C:\Users\DanielManuelPechoVeg\AppData\Local\Temp\ipykernel_2420\1334052949.py:17: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   cmap = get_cmap("turbo")   # O "viridis", "plasma", "rainbow"
# C:\Users\DanielManuelPechoVeg\AppData\Local\Temp\ipykernel_2420\559485741.py:33: RuntimeWarning: invalid value encountered in power
#   term1 = (1 / 7**(2/3)) * r2**(2/3) * big_term**(1/3)
# C:\Users\DanielManuelPechoVeg\AppData\Local\Temp\ipykernel_2420\559485741.py:43: RuntimeWarning: invalid value encountered in power
#   term2 = ((7 - 108*b) * r2**(10/3)) / (big_term2**(1/3))
# C:\Users\DanielManuelPechoVeg\AppData\Local\Temp\ipykernel_2420\559485741.py:43: RuntimeWarning: divide by zero encountered in divide
#   term2 = ((7 - 108*b) * r2**(10/3)) / (big_term2**(1/3))
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[5], line 33
#      31 for i, b in enumerate(b_list):
#      32     for j, alpha in enumerate(alpha_list):
# ---> 33         ax = axes[i, j]
#      35         for k, mu in enumerate(mu_list):
#      36             color = cmap(k / (len(mu_list) - 1))
#
# IndexError: index 1 is out of bounds for axis 0 with size 1

# %%
r_vals = np.linspace(0, 10, 10000)
mu_list = [0.05, 0.1, 0.2, 0.5, 1, 2, 4, 8]
b_list = [round(8/108,4), 1/8, 1/4, 1/2, 1, 2, 4]

plt.rcParams.update({
    "font.family": "serif",
    "font.size": 12,
    "figure.dpi": 300,
    "axes.labelsize": 14,
    "axes.titlesize": 16,
    "legend.fontsize": 12,
    "lines.linewidth": 2
})

cmap = get_cmap("turbo")

# 👉 Filas = b, una sola columna
fig, axes = plt.subplots(
    nrows=len(b_list),
    ncols=1,
    figsize=(5, 3.5 * len(b_list)),
    sharex=True,
    sharey=True
)

axes = np.atleast_1d(axes)

for i, b in enumerate(b_list):
    ax = axes[i]

    for k, mu in enumerate(mu_list):
        color = cmap(k / (len(mu_list) - 1))
        ax.plot(
            r_vals,
            f3rees1(r_vals, b, mu),
            color=color
        )

    ax.set_title(fr"$b={b}$")
    ax.grid(True, alpha=0.3)

    if i == len(b_list) - 1:
        ax.set_xlabel("$r$")

    if i == len(b_list)//2:
        ax.set_ylabel("$f(r)$")

# Leyenda a la derecha
handles = [
    plt.Line2D([0], [0], color=cmap(k/(len(mu_list)-1)), lw=2)
    for k in range(len(mu_list))
]
labels = [fr"$\mu={mu}$" for mu in mu_list]

fig.legend(
    handles, labels,
    title="Valores de $\mu$",
    loc="center left",
    bbox_to_anchor=(1.02, 0.5),
    frameon=True,
    fontsize=18,
    title_fontsize=18,
    borderpad=1.2,      # espacio interno
    labelspacing=1.2    # espacio entre líneas
)

plt.tight_layout(rect=[0, 0, 0.85, 1])  # 👈 deja espacio a la derecha
plt.savefig("beta.png", dpi=300, bbox_inches="tight")
plt.show()
# Out:
# C:\Users\DanielManuelPechoVeg\AppData\Local\Temp\ipykernel_2420\1938546857.py:15: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   cmap = get_cmap("turbo")
# C:\Users\DanielManuelPechoVeg\AppData\Local\Temp\ipykernel_2420\559485741.py:33: RuntimeWarning: invalid value encountered in power
#   term1 = (1 / 7**(2/3)) * r2**(2/3) * big_term**(1/3)
# C:\Users\DanielManuelPechoVeg\AppData\Local\Temp\ipykernel_2420\559485741.py:43: RuntimeWarning: invalid value encountered in power
#   term2 = ((7 - 108*b) * r2**(10/3)) / (big_term2**(1/3))
# C:\Users\DanielManuelPechoVeg\AppData\Local\Temp\ipykernel_2420\559485741.py:43: RuntimeWarning: divide by zero encountered in divide
#   term2 = ((7 - 108*b) * r2**(10/3)) / (big_term2**(1/3))
# C:\Users\DanielManuelPechoVeg\AppData\Local\Temp\ipykernel_2420\559485741.py:43: RuntimeWarning: invalid value encountered in divide
#   term2 = ((7 - 108*b) * r2**(10/3)) / (big_term2**(1/3))
